// %%
import { firstCell } from "./notebook.ts";

Deno.jupyter.html`${await firstCell()}`;
// Out:
// <p>0 / 33677</p><table><thead><tr><th>path</th><th>remoteIp</th><th>statusCode</th><th>statusText</th></tr></thead><tbody></tbody></table>
